# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot

# %%
#list vs array
list0=[1,2,3,4,5,6]

# %%
array1=np.array([1,2,3,4,5,6])

# %%
array1*4
# Out:
# array([ 4,  8, 12, 16, 20, 24])

# %%
list0*4
# Out:
# [1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6]

# %%
# creating random data
#difference between rand and randn and uniform

# %%
df=pd.DataFrame(np.random.randn(100))
df.plot.kde()

# %%
df=pd.DataFrame(np.random.rand(100))
df.plot.kde()

# %%
df=pd.DataFrame(np.random.uniform(1,100,2000))
df.plot.kde()

# %%
#creating array of different shapes
np.random.rand(4,5)
# Out:
# array([[0.08842942, 0.41143119, 0.02358768, 0.5356176 , 0.77655207],
#        [0.55239567, 0.4491089 , 0.94640632, 0.30704873, 0.80459619],
#        [0.97890667, 0.71464355, 0.89430487, 0.82224744, 0.3551888 ],
#        [0.49930593, 0.49468098, 0.39473713, 0.94433782, 0.35840241]])

# %%
array1=np.random.rand(4,5)

# %%
array1.shape
# Out:
# (4, 5)

# %%
#it will generate numbers 
np.linspace(1,10,5)
# Out:
# array([ 1.  ,  3.25,  5.5 ,  7.75, 10.  ])

# %%
np.argmax(array1)
# Out:
# 14

# %%
np.max(array1)
# Out:
# 0.9893675414849983

# %%
np.min(array1)
# Out:
# 0.060763825802807814

# %%
np.sum(array1)
# Out:
# 9.685612485000586

# %%
array1
# Out:
# array([[0.36004289, 0.64959612, 0.43515924, 0.25193468, 0.13957834],
#        [0.38341608, 0.14237382, 0.54904028, 0.79556529, 0.40973561],
#        [0.59093036, 0.69377413, 0.71084974, 0.95543251, 0.98936754],
#        [0.18374607, 0.80335254, 0.06076383, 0.29127113, 0.28968229]])

# %%
array1=array1.reshape(5,2,2)

# %%
array1
# Out:
# array([[[0.36004289, 0.64959612],
#         [0.43515924, 0.25193468]],
#
#        [[0.13957834, 0.38341608],
#         [0.14237382, 0.54904028]],
#
#        [[0.79556529, 0.40973561],
#         [0.59093036, 0.69377413]],
#
#        [[0.71084974, 0.95543251],
#         [0.98936754, 0.18374607]],
#
#        [[0.80335254, 0.06076383],
#         [0.29127113, 0.28968229]]])

# %%
array1[3][0,0]
# Out:
# 0.7108497423740082
